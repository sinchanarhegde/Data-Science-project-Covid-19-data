# %% [markdown]
# <a href="https://colab.research.google.com/github/sinchanarhegde/Data-Science-project/blob/main/Project_part2(loan_data_set).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Solution for Loan data set part 2:

# %%
import pandas as pd

# %%
df1=pd.read_csv("C:/Users/9OIN/OneDrive/Desktop/Project Documents/loan_data_set.csv", sep=",")

# %%
df1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ## Data Exploration:

# %%
df1.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df1.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# ## Data Cleaning:

# %%
df1.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df1.ffill(inplace=True)
df1.bfill(inplace=True)

# %%
df1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# #### creating seperate columns for categorical feature values:

# %%
df2=pd.get_dummies(df1,columns=["Gender","Married","Dependents","Education","Self_Employed","Property_Area","Loan_Status"])

# %%
df2
# Out:
#       Loan_ID  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0    LP001002             5849                0.0       128.0
# 1    LP001003             4583             1508.0       128.0
# 2    LP001005             3000                0.0        66.0
# 3    LP001006             2583             2358.0       120.0
# 4    LP001008             6000                0.0       141.0
# ..        ...              ...                ...         ...
# 609  LP002978             2900                0.0        71.0
# 610  LP002979             4106                0.0        40.0
# 611  LP002983             8072              240.0       253.0
# 612  LP002984             7583                0.0       187.0
# 613  LP002990             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History  Gender_Female  Gender_Male  Married_No  \
# 0               360.0             1.0          False         True        True
# ...

# %%
df2.dtypes
# Out:
# Loan_ID                     object
# ApplicantIncome              int64
# CoapplicantIncome          float64
# LoanAmount                 float64
# Loan_Amount_Term           float64
# Credit_History             float64
# Gender_Female                 bool
# Gender_Male                   bool
# Married_No                    bool
# Married_Yes                   bool
# Dependents_0                  bool
# Dependents_1                  bool
# Dependents_2                  bool
# Dependents_3+                 bool
# Education_Graduate            bool
# Education_Not Graduate        bool
# Self_Employed_No              bool
# Self_Employed_Yes             bool
# Property_Area_Rural           bool
# Property_Area_Semiurban       bool
# Property_Area_Urban           bool
# Loan_Status_N                 bool
# Loan_Status_Y                 bool
# dtype: object

# %%
df2.drop("Gender_Female",axis=1,inplace=True)

# %%
df2
# Out:
#       Loan_ID  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0    LP001002             5849                0.0       128.0
# 1    LP001003             4583             1508.0       128.0
# 2    LP001005             3000                0.0        66.0
# 3    LP001006             2583             2358.0       120.0
# 4    LP001008             6000                0.0       141.0
# ..        ...              ...                ...         ...
# 609  LP002978             2900                0.0        71.0
# 610  LP002979             4106                0.0        40.0
# 611  LP002983             8072              240.0       253.0
# 612  LP002984             7583                0.0       187.0
# 613  LP002990             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History  Gender_Male  Married_No  Married_Yes  \
# 0               360.0             1.0         True        True        False
# ...

# %%
df2.drop("Married_No",axis=1,inplace=True)

# %%
df2.drop("Dependents_3+",axis=1,inplace=True)

# %%
df2.drop("Education_Graduate",axis=1,inplace=True)

# %%
df2.drop("Self_Employed_No",axis=1,inplace=True)

# %%
df2.drop("Property_Area_Rural",axis=1,inplace=True)

# %%
df2.drop("Loan_Status_N",axis=1,inplace=True)

# %%
df2
# Out:
#       Loan_ID  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0    LP001002             5849                0.0       128.0
# 1    LP001003             4583             1508.0       128.0
# 2    LP001005             3000                0.0        66.0
# 3    LP001006             2583             2358.0       120.0
# 4    LP001008             6000                0.0       141.0
# ..        ...              ...                ...         ...
# 609  LP002978             2900                0.0        71.0
# 610  LP002979             4106                0.0        40.0
# 611  LP002983             8072              240.0       253.0
# 612  LP002984             7583                0.0       187.0
# 613  LP002990             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History  Gender_Male  Married_Yes  Dependents_0  \
# 0               360.0             1.0         True        False          True
# ...

# %% [markdown]
# ## Filtering of data:

# %%
a=df2.iloc[:,2:15]

# %%
a
# Out:
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0       128.0             360.0             1.0
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# 3               2358.0       120.0             360.0             1.0
# 4                  0.0       141.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0        71.0             360.0             1.0
# 610                0.0        40.0             180.0             1.0
# 611              240.0       253.0             360.0             1.0
# 612                0.0       187.0             360.0             1.0
# 613                0.0       133.0             360.0             0.0
#
#      Gender_Male  Married_Yes  Dependents_0  Dependents_1  Dependents_2  \
# ...

# %%
b=df2.iloc[:,-1]

# %%
b
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 609     True
# 610     True
# 611     True
# 612     True
# 613    False
# Name: Loan_Status_Y, Length: 614, dtype: bool

# %% [markdown]
# ### Model Training:

# %%
from sklearn.model_selection import train_test_split

# %%
a_train,a_test,b_train,b_test=train_test_split(a,b,test_size=0.25,random_state=(0))

# %% [markdown]
# ### Logistic Regression:

# %%
from sklearn.linear_model import LogisticRegression

# %%
c=LogisticRegression(max_iter=10000)
c.fit(a_train,b_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
c_predict=c.predict(a_test)

# %% [markdown]
# ### Confusion Matrix:

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
acs=accuracy_score(b_test,c_predict)
cm=confusion_matrix(b_test,c_predict)

# %%
print(acs)
# Out:
# 0.8506493506493507

# %%
print(cm)
# Out:
# [[ 23  20]
#  [  3 108]]
